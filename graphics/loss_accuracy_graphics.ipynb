# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
loss = [
    92.90, 6.30, 1.39, 1.39, 1.39,
    1.39, 1.39, 1.39, 1.39, 1.39,
    1.39, 1.39, 1.39, 1.39, 1.39,
    1.39, 1.39, 1.39, 1.39, 1.39
]
accuracy = [
    0.2454, 0.2505, 0.2500, 0.2490, 0.2442,
    0.2459, 0.2438, 0.2471, 0.2451, 0.2464,
    0.2435, 0.2434, 0.2458, 0.2408, 0.2458,
    0.2438, 0.2449, 0.2452, 0.2501, 0.2451
    ]

# %%
graphfont = {'fontname':'Consolas'}

# %%
plt.figure(figsize=(6,2), dpi=150)
plt.plot(loss)
plt.title("Typical Model Loss over 20 Epochs", **graphfont)
plt.xlabel("Epochs", **graphfont)
plt.ylabel("Loss (SCGE)", **graphfont)
plt.xticks(**graphfont)
plt.yticks(**graphfont)
plt.show()

# %%
plt.figure(figsize=(6,2), dpi=150)
plt.plot(accuracy)
plt.title("Typical Model Accuracy over 20 Epochs", **graphfont)
plt.xlabel("Epochs", **graphfont)
plt.ylabel("Accuracy (% Correct)", **graphfont)
plt.xticks(**graphfont)
plt.yticks(**graphfont)
plt.ylim(0,1)
plt.show()

# %%
np.size(np.arange(1,21,1))
# Out:
# 19
